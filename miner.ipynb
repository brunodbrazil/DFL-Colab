# %%
# !sudo add-apt-repository ppa:ethereum/ethereum

# %%
# !sudo cat /etc/apt/sources.list

# %%
# !sudo apt update

# %%
# !sudo apt install ethereum

# %%
# !wget https://github.com/ethereum-mining/ethminer/releases/download/v0.18.0/ethminer-0.18.0-cuda-9-linux-x86_64.tar.gz

# %%
# %ls

# %%
# !tar -zxvf ethminer-0.18.0-cuda-9-linux-x86_64.tar.gz

# %%
# %cd bin/

# %%
# !ethminer -G -F http://eth-eu.dwarfpool.com:80/0x231b393ff62825940762b737e384b8718f598ba5

# %%
import IPython
from google.colab import output

display(IPython.display.Javascript('''
 function ClickConnect(){
   btn = document.querySelector("colab-connect-button")
   if (btn != null){
     console.log("Click colab-connect-button"); 
     btn.click() 
     }
   
   btn = document.getElementById('ok')
   if (btn != null){
     console.log("Click reconnect"); 
     btn.click() 
     }
  }
  
setInterval(ClickConnect,60000)
'''))

print("Done.")

# %%
# !./ethminer -G -P stratum1+tcp://0x2E13C93f7897AcF9c7Abf29041e5290e257aC726@us1.ethpool.org:3333
# Out:
# ethminer 0.18.0
# Build: linux/release/gnu
#
#  i 22:23:14 ethminer Configured pool us1.ethpool.org:3333
#  i 22:23:14 ethminer Selected pool us1.ethpool.org:3333
#  i 22:23:14 ethminer Stratum mode : Eth-Proxy compatible
#  i 22:23:14 ethminer Established connection to us1.ethpool.org [172.65.229.54:3333]
#  i 22:23:14 ethminer Spinning up miners...
# cl 22:23:14 cl-0     Using PciId : 00:00.4 Tesla P100-PCIE-16GB (Compute 6.0) Memory : 15.90 GB
#  i 22:23:14 ethminer Epoch : 339 Difficulty : 4.00 Gh
#  i 22:23:14 ethminer Job: 9e025a47… block 10195523 us1.ethpool.org [172.65.229.54:3333]
# cl 22:23:17 cl-0     Generating DAG + Light : 3.71 GB
#  i 22:23:17 ethminer Job: de61a092… block 10195523 us1.ethpool.org [172.65.229.54:3333]
# cl 22:23:17 cl-0     OpenCL kernel
# cl 22:23:17 cl-0     Creating light cache buffer, size: 58.37 MB
# cl 22:23:17 cl-0     Creating DAG buffer, size: 3.65 GB, free: 12.19 GB
# cl 22:23:17 cl-0     Loading kernels
# ...
